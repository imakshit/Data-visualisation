# %%
# library
import seaborn as sns
import pandas as pd
import numpy as np
 
# Create a dataset (fake)
df = pd.DataFrame(np.random.random((5,5)), columns=["a","b","c","d","e"])
print(df)
# Default heatmap: just a visualization of this square matrix
p1 = sns.heatmap(df)
# Out:
#           a         b         c         d         e
# 0  0.616216  0.393094  0.266124  0.580556  0.401181
# 1  0.668496  0.671284  0.858774  0.191305  0.362397
# 2  0.127615  0.135613  0.021004  0.339704  0.863238
# 3  0.066006  0.211829  0.756419  0.137109  0.653937
# 4  0.848309  0.996125  0.361812  0.922998  0.090898

# %%
#annot=True will add a label into each cell, providing the exact value behind the color.
sns.heatmap(df, annot=True, annot_kws={"size": 7})
